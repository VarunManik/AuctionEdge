# %%
import pandas as pd

# %%
import pandas as pd
import json

file_path = r"C:\Users\Denve\Desktop\AuctionHelper\PPL-6Config.xlsx"  # Replace with your file path
df = pd.read_excel(file_path)

df.columns = ["FORM NO","Name","Role", "Category","Image Location"]

# df['Category'] = df['Category'].replace("A+", "Icon")
df['Role'] = df['Role'].replace("All Rounder", "ALL_ROUNDER")

final_list = df.to_dict(orient="records")
df.clip

output = {"FullPlayerList": final_list}

with open(r"C:\Users\Denve\Desktop\AuctionHelper\output.json", "w") as json_file:
    json.dump(output, json_file, indent=4)

print("JSON conversion complete. Check output.json.")
# Out:
# JSON conversion complete. Check output.json.

# %%
import os

# Specify the folder path
folder_path = r"C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics"

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    
    # Ensure it's a file (not a folder)
    if os.path.isfile(file_path):
        print(f"{file_path}")
# Out:
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\1.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\10.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\101.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\102.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\103.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\105.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\106.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\107.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\108.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\109.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\11.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\110.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\111.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\112.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\113.jpg
# C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\114.jpg
# ...

# %%
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\1.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\10.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\101.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\102.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\103.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\105.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\106.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\107.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\108.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\109.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\11.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\110.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\111.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\112.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\113.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\114.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\116.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\118.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\119.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\12.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\120.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\123.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\124.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\125.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\126.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\127.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\128.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\129.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\13.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\130.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\131.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\132.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\133.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\134.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\135.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\136.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\137.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\14.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\143.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\144.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\145.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\15.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\16.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\17.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\18.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\19.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\2.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\21.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\22.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\23.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\25.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\26.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\27.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\29.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\3.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\30.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\31.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\34.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\35.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\36.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\37.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\38.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\39.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\4.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\40.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\41.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\42.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\44.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\45.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\46.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\47.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\48.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\49.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\5.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\50.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\51.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\52.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\53.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\56.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\57.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\58.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\59.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\6.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\60.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\61.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\63.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\64.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\65.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\67.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\7.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\75.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\77.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\78.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\79.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\8.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\80.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\81.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\82.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\83.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\85.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\86.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\87.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\88.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\89.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\9.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\90.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\91.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\92.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\94.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\95.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\96.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\97.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\98.jpg
C:\Users\Denve\Desktop\PPL\Player Pics\Player Pics\99.jpg
